# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from pandas import DataFrame, Series

# %% [markdown]
# # Datos

# %%
PD = 0.5
alpha = 141.2
qo = 7961 #BPD
Bo = 1.25
Muo = 0.5
k = 278
h = 492.1259843
tD_entre_rd_sqrd = 5
r = 1968.503937 
phi = 0.055
Ct = 4e-5
beta = 2.637e-4
k = 278

# %%
delta_p = PD * alpha * qo * Bo * Muo /( k * h)
print(f"{delta_p:.5f}", "[psi]")
# Out:
# 2.56762 [psi]

# %%
t = tD_entre_rd_sqrd * r **2 * phi * Muo * Ct / (beta * k)
print(f"{t:.5f}", "[horas]")
# Out:
# 290.72363 [horas]
